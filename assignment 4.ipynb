# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mlt

# %% [markdown]
# ### assignment 01

# %%
j=pd.read_csv('./C:/users/My Dell/gm_2008_region.csv')
j
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-416dbc729ffb> in <module>()
# ----> 1 j=pd.read_csv('./C:/users/My Dell/gm_2008_region.csv')
#       2 j
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
print(j["Region"].unique())
j.boxplot("life","Region")
# Out:
# ['Middle East & North Africa' 'Sub-Saharan Africa' 'America'
#  'Europe & Central Asia' 'East Asia & Pacific' 'South Asia']

# %%
df=pd.get_dummies(j)
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0       2.73  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0       6.43  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0       2.24  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0       1.40  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0       1.96  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality  Region_America  Region_East Asia & Pacific  \
# 0             29.5               0                           0
# 1            192.0               0                           0
# 2             15.4               1                           0
# 3             20.0               0                           0
# 4              5.2               0                           1
#
#    Region_Europe & Central Asia  Region_Middle East & North Africa  \
# ...

# %%
df = df.drop("Region_America", axis = 1)
df.head()
# Out:
#    population  fertility  HIV        CO2  BMI_male      GDP  BMI_female  life  \
# 0  34811059.0       2.73  0.1   3.328945  24.59620  12314.0    129.9049  75.3
# 1  19842251.0       6.43  2.0   1.474353  22.25083   7103.0    130.1247  58.3
# 2  40381860.0       2.24  0.5   4.785170  27.50170  14646.0    118.8915  75.5
# 3   2975029.0       1.40  0.1   1.804106  25.35542   7383.0    132.8108  72.5
# 4  21370348.0       1.96  0.1  18.016313  27.56373  41312.0    117.3755  81.5
#
#    child_mortality  Region_East Asia & Pacific  Region_Europe & Central Asia  \
# 0             29.5                           0                             0
# 1            192.0                           0                             0
# 2             15.4                           0                             0
# 3             20.0                           0                             1
# 4              5.2                           1                             0
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
X = df.drop("life",axis = 1).values
y = df["life"].values
print(X[:10])
print(y[:10])
lr = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.4,random_state=12)
# Out:
# [[3.48110590e+07 2.73000000e+00 1.00000000e-01 3.32894466e+00
#   2.45962000e+01 1.23140000e+04 1.29904900e+02 2.95000000e+01
#   0.00000000e+00 0.00000000e+00 1.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [1.98422510e+07 6.43000000e+00 2.00000000e+00 1.47435339e+00
#   2.22508300e+01 7.10300000e+03 1.30124700e+02 1.92000000e+02
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   1.00000000e+00]
#  [4.03818600e+07 2.24000000e+00 5.00000000e-01 4.78516998e+00
#   2.75017000e+01 1.46460000e+04 1.18891500e+02 1.54000000e+01
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [2.97502900e+06 1.40000000e+00 1.00000000e-01 1.80410622e+00
#   2.53554200e+01 7.38300000e+03 1.32810800e+02 2.00000000e+01
#   0.00000000e+00 1.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [2.13703480e+07 1.96000000e+00 1.00000000e-01 1.80163133e+01
#   2.75637300e+01 4.13120000e+04 1.17375500e+02 5.20000000e+00
# ...

# %%
print(lr.fit(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
# 0.7813093897303417

# %%
j.boxplot("HIV","Region")

# %%
b=pd.read_csv('./house-votes-84.csv')
b.head()
# Out:
#    republican  n  y n.1 y.1 y.2 y.3 n.2 n.3 n.4 y.4  ? y.5 y.6 y.7 n.5 y.8
# 0  republican  n  y   n   y   y   y   n   n   n   n  n   y   y   y   n   ?
# 1    democrat  ?  y   y   ?   y   y   n   n   n   n  y   n   y   y   n   n
# 2    democrat  n  y   y   n   ?   y   n   n   n   n  y   n   y   n   n   y
# 3    democrat  y  y   y   n   y   y   n   n   n   n  y   ?   y   y   y   y
# 4    democrat  n  y   y   n   y   y   n   n   n   n  n   n   y   y   y   y

# %%
z=pd.read_csv('./white-wine.csv')
z.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
from sklearn.preprocessing import scale
g=
scale(total sulfurdioxide)
# Out:
#   File "<ipython-input-38-da48884ebcdf>", line 2
#     scale(total sulfurdioxide)
#                             ^
# SyntaxError: invalid syntax

# %%
k=pd.read_csv('./house-votes-84-updated.csv')
k.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-2515a0f5106f> in <module>()
# ----> 1 k=pd.read_csv('./house-votes-84-updated.csv')
#       2 k.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...
